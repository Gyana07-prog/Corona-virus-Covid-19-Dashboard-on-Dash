# %%
import numpy as np
import pandas as pd

# %%
patients = pd.read_csv('C:\\Users\\gyanr\\OneDrive\\Desktop\\Dash\\Covid_19\\IndividualDetails.csv')
patients
# Out:
#         id government_id diagnosed_date  age gender             detected_city  \
# 0        0      KL-TS-P1     30/01/2020   20      F                  Thrissur
# 1        1      KL-AL-P1     02/02/2020  NaN    NaN                 Alappuzha
# 2        2      KL-KS-P1     03/02/2020  NaN    NaN                 Kasaragod
# 3        3         DL-P1     02/03/2020   45      M  East Delhi (Mayur Vihar)
# 4        4         TS-P1     02/03/2020   24      M                 Hyderabad
# ...    ...           ...            ...  ...    ...                       ...
# 8467  8468           NaN     12/04/2020  NaN    NaN                       NaN
# 8468  8469           NaN     12/04/2020  NaN    NaN                       NaN
# 8469  8470           NaN     12/04/2020  NaN    NaN                       NaN
# 8470  8471           NaN     12/04/2020  NaN    NaN                       NaN
# 8471  8472           NaN     12/04/2020  NaN    NaN                       NaN
#
#      detected_district detected_state nationality current_status  \
# 0             Thrissur         Kerala       India      Recovered
# 1            Alappuzha         Kerala       India      Recovered
# 2            Kasaragod         Kerala       India      Recovered
# 3           East Delhi          Delhi       India      Recovered
# 4            Hyderabad      Telangana       India      Recovered
# ...                ...            ...         ...            ...
# 8467               NaN    West Bengal         NaN   Hospitalized
# 8468               NaN    West Bengal         NaN   Hospitalized
# 8469               NaN    West Bengal         NaN   Hospitalized
# 8470               NaN    West Bengal         NaN   Hospitalized
# 8471               NaN    West Bengal         NaN   Hospitalized
#
#      status_change_date                                              notes
# 0            14/02/2020                               Travelled from Wuhan
# 1            14/02/2020                               Travelled from Wuhan
# 2            14/02/2020                               Travelled from Wuhan
# 3            15/03/2020                      Travelled from Austria, Italy
# 4            02/03/2020  Travelled from Dubai to Bangalore on 20th Feb,...
# ...                 ...                                                ...
# 8467         12/04/2020                                                NaN
# 8468         12/04/2020                                                NaN
# 8469         12/04/2020                                                NaN
# 8470         12/04/2020                                                NaN
# 8471         12/04/2020                                                NaN
#
# [8472 rows x 12 columns]

# %%
patients['current_status'].value_counts()
# Out:
# current_status
# Hospitalized    8301
# Recovered        139
# Deceased          30
# Migrated           1
# Name: count, dtype: int64

# %%
totalpatients = patients.shape[0]
active = patients[patients['current_status'] == 'Hospitalized'].shape[0]
recovered = patients[patients['current_status'] == 'Recovered'].shape[0]
deaths = patients[patients['current_status'] == 'Deceased'].shape[0]

# %%
active = patients[patients['current_status'] == 'Hospitalized'].shape[0]

# %%
patients
# Out:
#         id government_id diagnosed_date  age gender             detected_city  \
# 0        0      KL-TS-P1     30/01/2020   20      F                  Thrissur
# 1        1      KL-AL-P1     02/02/2020  NaN    NaN                 Alappuzha
# 2        2      KL-KS-P1     03/02/2020  NaN    NaN                 Kasaragod
# 3        3         DL-P1     02/03/2020   45      M  East Delhi (Mayur Vihar)
# 4        4         TS-P1     02/03/2020   24      M                 Hyderabad
# ...    ...           ...            ...  ...    ...                       ...
# 8467  8468           NaN     12/04/2020  NaN    NaN                       NaN
# 8468  8469           NaN     12/04/2020  NaN    NaN                       NaN
# 8469  8470           NaN     12/04/2020  NaN    NaN                       NaN
# 8470  8471           NaN     12/04/2020  NaN    NaN                       NaN
# 8471  8472           NaN     12/04/2020  NaN    NaN                       NaN
#
#      detected_district detected_state nationality current_status  \
# 0             Thrissur         Kerala       India      Recovered
# 1            Alappuzha         Kerala       India      Recovered
# 2            Kasaragod         Kerala       India      Recovered
# 3           East Delhi          Delhi       India      Recovered
# 4            Hyderabad      Telangana       India      Recovered
# ...                ...            ...         ...            ...
# 8467               NaN    West Bengal         NaN   Hospitalized
# 8468               NaN    West Bengal         NaN   Hospitalized
# 8469               NaN    West Bengal         NaN   Hospitalized
# 8470               NaN    West Bengal         NaN   Hospitalized
# 8471               NaN    West Bengal         NaN   Hospitalized
#
#      status_change_date                                              notes
# 0            14/02/2020                               Travelled from Wuhan
# 1            14/02/2020                               Travelled from Wuhan
# 2            14/02/2020                               Travelled from Wuhan
# 3            15/03/2020                      Travelled from Austria, Italy
# 4            02/03/2020  Travelled from Dubai to Bangalore on 20th Feb,...
# ...                 ...                                                ...
# 8467         12/04/2020                                                NaN
# 8468         12/04/2020                                                NaN
# 8469         12/04/2020                                                NaN
# 8470         12/04/2020                                                NaN
# 8471         12/04/2020                                                NaN
#
# [8472 rows x 12 columns]

# %%
npat = patients[patients['current_status'] == 'Recovered']
pbar = npat['detected_state'].value_counts().reset_index()
# patients.groupby('detected_state')['current_status'].count()

# %%
pbar
# Out:
#       detected_state  count
# 0             Kerala     58
# 1          Karnataka     39
# 2            Haryana     12
# 3      Uttar Pradesh      6
# 4         Tamil Nadu      6
# 5          Rajasthan      3
# 6        West Bengal      3
# 7              Delhi      2
# 8     Andhra Pradesh      2
# 9        Maharashtra      2
# 10         Telangana      1
# 11      Chhattisgarh      1
# 12       Uttarakhand      1
# 13           Gujarat      1
# 14  Himachal Pradesh      1
# 15           Manipur      1

# %%
npat
# Out:
#         id government_id diagnosed_date  age gender             detected_city  \
# 0        0      KL-TS-P1     30/01/2020   20      F                  Thrissur
# 1        1      KL-AL-P1     02/02/2020  NaN    NaN                 Alappuzha
# 2        2      KL-KS-P1     03/02/2020  NaN    NaN                 Kasaragod
# 3        3         DL-P1     02/03/2020   45      M  East Delhi (Mayur Vihar)
# 4        4         TS-P1     02/03/2020   24      M                 Hyderabad
# ...    ...           ...            ...  ...    ...                       ...
# 1078  1078        TN-P46     29/03/2020   51      F                       NaN
# 1248  1248           NaN     30/03/2020  NaN    NaN                       NaN
# 1249  1249           NaN     30/03/2020  NaN    NaN                       NaN
# 1250  1250           NaN     30/03/2020  NaN    NaN                       NaN
# 1260  1260           NaN     30/03/2020  NaN    NaN                       NaN
#
#      detected_district detected_state nationality current_status  \
# 0             Thrissur         Kerala       India      Recovered
# 1            Alappuzha         Kerala       India      Recovered
# 2            Kasaragod         Kerala       India      Recovered
# 3           East Delhi          Delhi       India      Recovered
# 4            Hyderabad      Telangana       India      Recovered
# ...                ...            ...         ...            ...
# 1078             Erode     Tamil Nadu       India      Recovered
# 1248            Kannur         Kerala         NaN      Recovered
# 1249            Kannur         Kerala         NaN      Recovered
# 1250            Kannur         Kerala         NaN      Recovered
# 1260           Wayanad         Kerala         NaN      Recovered
#
#      status_change_date                                              notes
# 0            14/02/2020                               Travelled from Wuhan
# 1            14/02/2020                               Travelled from Wuhan
# 2            14/02/2020                               Travelled from Wuhan
# 3            15/03/2020                      Travelled from Austria, Italy
# 4            02/03/2020  Travelled from Dubai to Bangalore on 20th Feb,...
# ...                 ...                                                ...
# 1078         06/04/2020                                  Contact of TN-P43
# 1248         04/04/2020                                    Details awaited
# 1249         05/04/2020                                    Details awaited
# 1250         05/04/2020                                    Details awaited
# 1260         08/04/2020                                    Details awaited
#
# [139 rows x 12 columns]
